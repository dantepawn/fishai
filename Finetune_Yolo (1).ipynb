# %% [markdown]
# # Setup

# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 80.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 59.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 111.1 MB/s eta 0:00:00

# %%
import numpy as np
from tqdm import tqdm
import cv2
from pathlib import Path

# %%
from ultralytics import YOLO

#model = YOLO("yolo11x-pose.yaml")  # build a new model from YAML
model = YOLO("yolo11x-pose.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 113M/113M [00:00<00:00, 474MB/s]

# %% [markdown]
# # Optional for tracking training

# %%
from ultralytics import settings

settings.update({"runs_dir": "/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO/runs/" , "tensorboard": True})
settings.update({"mlflow": True})

# %%
host = 'https://dbc-c96b0710-073b.cloud.databricks.com/'
api_token_location = '/datascience/Fish/databricks/'
api_token = "dapi400b454b0fff721b0001a47a584b7cc6"

# %%
# %pip install -q mlflow

import mlflow

mlflow.login()

mlflow.set_tracking_uri("databricks")
mlflow.set_experiment("/Users/daniel.pavlicek@gmail.com/yolo11-keypoints")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.0/29.0 MB 92.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 142.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 25.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 700.2/700.2 kB 56.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 23.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 9.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Training

# %%
import torch

torch.cuda.empty_cache()

# %%
results = model.train(
    data="/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO_train.yaml",
    cfg="/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/hyp.yaml",
    epochs=350,  # Total epochs (50 additional)
    imgsz=1024,  # Increased resolution
    batch=8,  # Manually set lower batch
    amp=True,
    #cos_lr=True,
    augment=True,
    close_mosaic=50,  # Earlier mosaic disable
    device=0,
)
# Out:
# Ultralytics 8.3.133 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %% [markdown]
# ### save checkpoints

# %%
import shutil
shutil.copytree("/content/runs/pose/train", "/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO/runs/pose/train17/")
# Out:
# '/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO/runs/pose/train17/'

# %%
# !yolo settings
# Out:
# JSONDict("/root/.config/Ultralytics/settings.json"):
# {
#   "settings_version": "0.0.6",
#   "datasets_dir": "/content/datasets",
#   "weights_dir": "weights",
#   "runs_dir": "/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO/runs/",
#   "uuid": "569f3ba64b326db489132663f79cd37279811de477381b83ac131e6cdd129cbb",
#   "sync": true,
#   "api_key": "",
#   "openai_api_key": "",
#   "clearml": true,
#   "comet": true,
#   "dvc": true,
#   "hub": true,
#   "mlflow": true,
#   "neptune": true,
#   "raytune": true,
#   "tensorboard": true,
#   "wandb": false,
#   "vscode_msg": true
# }
# 💡 Learn more about Ultralytics Settings at https://docs.ultralytics.com/quickstart/#ultralytics-settings

# %% [markdown]
# # Train for addition al 50 epochs

# %%
results = model.train(
    data="/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO_train.yaml",
    cfg="/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/hyp.yaml",
    epochs=50,  # Set to total desired epochs
    imgsz=1024,
    batch=8,
    amp=True,
    augment=True,
    close_mosaic=10,
    device=0,
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.130 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA L4, 22693MiB)
# ...

# %%
import shutil
shutil.copytree("/content/runs/pose/train2", "/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO/runs/pose/train16_2/")
# Out:
# '/content/drive/MyDrive/2023_24 Prototype 2.0/PESCI/Keypoints/YOLO/runs/pose/train16_2/'
